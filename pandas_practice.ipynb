# %%
import pandas as pd
import numpy as np

# %%
titanic = pd.read_csv("titanic.csv", index_col=['PassengerId'])
titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
# df = pd.read_csv("titanic.csv", usecols = [0, 1, 2, 5, 6, 7, 9])
# df

titanic.shape
# Out:
# (891, 11)

# %%
## Always position based - excludes last position when slicing

df = titanic.iloc[1:5] ## gets roews from 1st to 5th index
# df = titanic.iloc[:, 4] ## all rows with 4th column
# df = titanic.iloc[1:,] ## all rows except first, all columns
# # df = titanic.iloc[:5,] ## top 5 rows
df = titanic.iloc[1:5, 2:6] ## row index 1 to 5(total 4 rows), columns from 2-6(total 4)
# df = titanic.iloc[['Age']] # fails, needs an index
df = titanic.iloc[[1,3], [1, 2, 3]]  ## index 1 and 3 and column 1, 2, 3(index)
df = titanic.iloc[1:3, [1, 2, 3]]  ## index 1 and 2 and column 1, 2, 3(index)
df
# Out:
#              Pclass                                               Name     Sex
# PassengerId
# 2                 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                 3                             Heikkinen, Miss. Laina  female

# %%
## Boolean -
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[74], line 2
#       1 ## Boolean -
# ----> 2 df = titanic.iloc[[True, False], 1]
#       3 df
#
# File c:\Users\atalb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File c:\Users\atalb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1596, in _iLocIndexer._getitem_tuple(self, tup)
#    1594 tup = self._validate_tuple_indexer(tup)
#    1595 with suppress(IndexingError):
# -> 1596     return self._getitem_lowerdim(tup)
#    1598 return self._getitem_tuple_same_dim(tup)
#
# File c:\Users\atalb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1024, in _LocationIndexer._getitem_lowerdim(self, tup)
#    1022             return section
#    1023         # This is an elided recursive call to iloc/loc
# -> 1024         return getattr(section, self.name)[new_key]
#    1026 raise IndexingError("not applicable")
#
# File c:\Users\atalb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\atalb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1643, in _iLocIndexer._getitem_axis(self, key, axis)
#    1641 if com.is_bool_indexer(key):
#    1642     self._validate_key(key, axis)
# -> 1643     return self._getbool_axis(key, axis=axis)
#    1645 # a list of integers
#    1646 elif is_list_like_indexer(key):
#
# File c:\Users\atalb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1121, in _LocationIndexer._getbool_axis(self, key, axis)
#    1117 @final
#    1118 def _getbool_axis(self, key, axis: AxisInt):
#    1119     # caller is responsible for ensuring non-None axis
#    1120     labels = self.obj._get_axis(axis)
# -> 1121     key = check_bool_indexer(labels, key)
#    1122     inds = key.nonzero()[0]
#    1123     return self.obj._take_with_is_copy(inds, axis=axis)
#
# File c:\Users\atalb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:2525, in check_bool_indexer(index, key)
#    2521 elif not is_array_like(result):
#    2522     # GH 33924
#    2523     # key may contain nan elements, check_array_indexer needs bool array
#    2524     result = pd_array(result, dtype=bool)
# -> 2525 return check_array_indexer(index, result)
#
# File c:\Users\atalb\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexers\utils.py:541, in check_array_indexer(array, indexer)
#     539     # GH26658
#     540     if len(indexer) != len(array):
# --> 541         raise IndexError(
#     542             f"Boolean index has wrong length: "
#     543             f"{len(indexer)} instead of {len(array)}"
#     544         )
#     545 elif is_integer_dtype(dtype):
#     546     try:
#
# IndexError: Boolean index has wrong length: 2 instead of 891

# %%
## Always label based (whatever the label is) - slices are inclusive

df = titanic.loc[1:5] ## gets roews from 1st to 5th label
# df = titanic.loc[:, 4] ## does not work, loc in label based
df = titanic.loc[1:,] ## all rows from '1' label, all columns
df = titanic.loc[:5,] ## top 5 rows - upto label 5
# df

# %%
df = titanic.loc[[1, 3, 4]]  # gets 1st, 3rd, 4th row
df = titanic.loc[1, "Name"]  # name of the passenger for label index 1 (two arguments only)
# df = titanic.loc[1, "Name", "Age"]  # FAILS - .loc[row, col] takes two arguments only:
df = titanic.loc[1, ["Name", "Age"]] # name, age of the passenger for label index 1
df = titanic.loc[:, ["Name", "Age"]] # all rows, these columns
df = titanic.loc[1:5, ["Name", "Age"]] # 1-5 rows(labels), these columns
df = titanic.loc[[1, 5], ["Name", "Age"]] # Name age for index 1 and 5(label)
df = titanic.loc[[1, 5], "Name":"Age"] # Name, Sex, age for index 1 and 5(label)
# df
# Out:
#                                  Name   Sex   Age
# PassengerId
# 1             Braund, Mr. Owen Harris  male  22.0
# 5            Allen, Mr. William Henry  male  35.0

# %%
## boolean - 
df = titanic.loc[titanic["Age"] > 30, "Name"]  ## name with age > 30
df = titanic.loc[titanic["Age"] > 30, ["Name", "Age"]]  ## name, Age with age > 30
df
# Out:
#                                                           Name   Age
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 5                                     Allen, Mr. William Henry  35.0
# 7                                      McCarthy, Mr. Timothy J  54.0
# 12                                    Bonnell, Miss. Elizabeth  58.0
# ...                                                        ...   ...
# 874                                Vander Cruyssen, Mr. Victor  47.0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0
# 882                                         Markun, Mr. Johann  33.0
# 886                       Rice, Mrs. William (Margaret Norton)  39.0
# 891                                        Dooley, Mr. Patrick  32.0
#
# [305 rows x 2 columns]

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["Alice", "Bob", "Charlie", "Doggie", "Eli", "Facy", "Gautham", "Hek", "Issac", "Jacob"],
    "Age": [25, 30, 35, 20, 21, 19, 29, 18, 15, 40],
    "City": ["Delhi", "Mumbai", "Bangalore", "Lucknow", "Trichy", "Mumbai", "Bangalore", "Delhi", "Chennai", "New York"]
}, index=["a", "b", "c", "d", "e", "f", "g", "h", "i", "j"])

df
# Out:
#       Name  Age       City
# a    Alice   25      Delhi
# b      Bob   30     Mumbai
# c  Charlie   35  Bangalore
# d   Doggie   20    Lucknow
# e      Eli   21     Trichy
# f     Facy   19     Mumbai
# g  Gautham   29  Bangalore
# h      Hek   18      Delhi
# i    Issac   15    Chennai
# j    Jacob   40   New York

# %%
# df = df.iloc[[True, False, True, False, True, False, True, False, True, False], 1]
# df

# df.loc["a":"d"]  # rows with labels 'a' to 'd' (inclusive)
df.iloc[0:2] # 0-2 (2 exculsive)
# Out:
#     Name  Age    City
# a  Alice   25   Delhi
# b    Bob   30  Mumbai

# %%
# Select by label
# print(df.loc["a"])        # Row with index 'a'

# # Multiple labels
# print(df.loc[["a", "c"]]) # Rows 'a' and 'c'

# # Label slice (inclusive of 'c')
# print(df.loc["a":"c"])

# # Specific row + column
# print(df.loc["f", "City"])  # Mumbai

df.loc["c"]  ## all columns
# Out:
# Name      Charlie
# Age            35
# City    Bangalore
# Name: c, dtype: object
