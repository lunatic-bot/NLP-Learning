# %%
# Interview questions

# from pareto distribution to normal distribution - how to do it
# - Box cox transformation

# What technique we apply whether the distribution follows normal or gaussian
# - QQ plot

# Standard normal distribution?

# Mean meadian mode relation when the plaot is symmetrical, left skewed, right skewed

# difference bentween fit_transform and transform

# fit_predict?

# Difference between normalization and standardization

# %% [markdown]
# ### RNN
#
# ![alt text](introduction_to_recurrent_neural_network.webp)
#
# weight updation formula:
#
# ![alt text](12wULsk4M4HG12bZ5cB-bPA.webp)

# %% [markdown]
# ## LSTM (long short term memory)
#
# https://colah.github.io/posts/2015-08-Understanding-LSTMs/
#
# ![alt text](LSTM3-var-GRU.png)
#
#
# - Memory cell
# - Forget call
# - input gate
# - Ouput cell
#
#
# #### Operations:
# - Pointwise operation
# - Concatenation

# %%
# Why LSTM instead of RNN
# - Vanishig gradient problem
# - Context information in deep RNN{the gap is huge between the input and the output}
# -
