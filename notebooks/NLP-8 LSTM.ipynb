# %% [markdown]
# Problmes with RNN :
#
# Vanishing gradient
#
# context from long back was not getting
#
# Operations:
# - pointwise operation
# - Copy
# - Concatenation
# - Vector transfer

# %% [markdown]
# Components :
# - Memory cell
# - forget gate layer
# - Input layer
# - Output cell
